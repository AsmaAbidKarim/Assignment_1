# %%
import os

def get_filepaths(directory):
    file_paths = []  
    for root, directories, folders in os.walk(directory):
        for files in folders:
            file_path = os.path.join(root, files)
            file_paths.append(file_path)  
            ##print(file_path)     
    return file_paths  # Self-explanatory.
def file_Size(file):
    file_stats = os.stat(file)
    a=file_stats.st_size
    return a
def Arrange(file_paths):
    for i in range(len(file_paths)):
        for j in range(len(file_paths)):
            if(file_Size(file_paths[i])>file_Size(file_paths[j])):
                temp=file_paths[j]
                file_paths[j]=file_paths[i]
                file_paths[i]=temp
    return file_paths
        
    
    
Path=""
# Run the above function and store its results in a variable. 
Path =input("Enter the path.....")
full_file_paths = get_filepaths(Path)
print("""-------------------------Files before sorting-----------------------""")
for i in range(len(full_file_paths)):
    print(full_file_paths[i],"\n")
full_path=Arrange(full_file_paths)
print("""\n----------------------files in descending order of their respective sizes--------------\n""")
for i in range(len(full_file_paths)):
    print(full_path[i],"\n")
# Out:
# Enter the path.....E:\asma 1\iba\semmester 3\Intro to social and cultural authropology
# -------------------------Files before sorting-----------------------
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Intro to Anthropology Fall 2020-compressed.mp3
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Intro to Anthropology Fall 2020.pdf
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\links to  videos and audio.docx
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Mid Term_Asma Abid Karim-19685.docx
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Week 1 Intro- Fall 2020.pptx
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Week 2 - Robins.pdf
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\week 2 Culture and Ethnography.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\week 3-1 language and reality.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\week 4 - Economic and Political Systems II power, authority and exchange.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Week 4- Economic and Political Systems I production.ppt
#
#
# ----------------------files in descending order of their respective sizes--------------
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Intro to Anthropology Fall 2020.pdf
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Week 2 - Robins.pdf
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Intro to Anthropology Fall 2020-compressed.mp3
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\week 4 - Economic and Political Systems II power, authority and exchange.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\week 3-1 language and reality.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\week 2 Culture and Ethnography.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Week 1 Intro- Fall 2020.pptx
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Week 4- Economic and Political Systems I production.ppt
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\Mid Term_Asma Abid Karim-19685.docx
#
# E:\asma 1\iba\semmester 3\Intro to social and cultural authropology\links to  videos and audio.docx

# %%
import requests
from bs4 import BeautifulSoup
import os
URL="https://www.facebook.com/"
Handle="Enter the handle"
list_likes=["Likes"]
list_Handles=["Handle"]
def print_likes_Handles():
    for i in range(len(list_likes)):
        print(list_Handles[i],"       ||     ",list_likes[i],"\n")
while(URL!=""):
    Handle=input("Enter The URL Or Press Enter To terminate....https://www.facebook.com/")
    URL= URL+Handle
    if(Handle!=""):
        response=requests.get(URL)
        str=response.content.decode()
        soup = BeautifulSoup(str,'lxml')
        ##The likes are in span tag inside class "_4-u3 _5sqi _5sqk
        f= soup.find('div', attrs={'class': '_4-u3 _5sqi _5sqk'})
        likes=f.find('span',attrs={'class':'_52id _50f5 _50f7'}) 
        #finding span tag inside class
        ##lik=str(likes)
        list_Handle = os.path.join(Handle)
        list_Handles.append(list_Handle)
        list_like = os.path.join(likes.text)
        list_likes.append(list_like)
        print(likes.text)
        print_likes_Handles()
        URL="https://www.facebook.com/"
    
    else:
        break
# Out:
# Enter The URL Or Press Enter To terminate....https://www.facebook.com/hamdabid15/
# ‏237‏ ‏لائکس‏
# Handle        ||      Likes
#
# hamdabid15/        ||      ‏237‏ ‏لائکس‏
#
# Enter The URL Or Press Enter To terminate....https://www.facebook.com/halcyonherald/
# ‏1,096,311‏ ‏لائکس‏
# Handle        ||      Likes
#
# hamdabid15/        ||      ‏237‏ ‏لائکس‏
#
# halcyonherald/        ||      ‏1,096,311‏ ‏لائکس‏
#
# Enter The URL Or Press Enter To terminate....https://www.facebook.com/

# %%
import requests
from bs4 import BeautifulSoup
import os
School_Names=[]
Out_School_name=[]
Out_physical_address=[]
Out_Principal_Name=[]
Out_Principal_Position=[]
Out_Principal_Email=[]
Out_School_Telephone_number=[]
Output=[]
##<a class="nav-link au-target" click.delegate="schoolDetails(school)" au-target-id="69">Acacia Hill School</a>
##<section id="search-panel-container" class="search-panel__content">

                                                           

def All_School_Name():
    School_Text=('a[itemprop=="text"]')
def Select_Letter(response):
    str=response.content.decode()
    ##print(str)
    soup = BeautifulSoup(str,'html.parser')
    Names=soup.select(".nav-item")
    for i in Names:
        Name_text= i.select_one('a[click.delegate="schoolDetails(school)"]').text
        School_Names.append(Name_text)
    return School_Names    
URL="https://directory.ntschools.net/#/schools"                                    
response=requests.get("https://directory.ntschools.net/#/schools")
School_Names=Select_Letter(response)
print(School_Names)
